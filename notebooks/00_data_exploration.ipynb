# %% [markdown]
# # Data Exploration
#
# This notebook explores the aircraft sensor timeseries data.

# %%
import sys
sys.path.insert(0, '../src')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from airtrace.viz.notebooks_utils import setup_notebook
setup_notebook()

# %% [markdown]
# ## Load Data
#
# Load raw or processed flight data for exploration.

# %%
# Example: Load a single flight
# flight_df = pd.read_parquet('../data/raw/flight_001.parquet')
# flight_df.head()

# %% [markdown]
# ## Visualize Sensor Distributions
#
# Explore the distributions of different sensors.

# %%
# Example: Plot sensor distributions
# flight_df.hist(figsize=(15, 10), bins=50)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Correlation Analysis
#
# Analyze correlations between sensors.

# %%
# Example: Correlation heatmap
# plt.figure(figsize=(10, 8))
# sns.heatmap(flight_df.corr(), annot=True, cmap='coolwarm', center=0)
# plt.title('Sensor Correlation Matrix')
# plt.show()

# %% [markdown]
# ## Time Series Visualization
#
# Plot sensor timeseries to understand temporal patterns.

# %%
# Example: Plot timeseries
# from airtrace.viz.plots import plot_timeseries
# 
# fig = plot_timeseries(
#     data=flight_df.values,
#     sensor_names=flight_df.columns.tolist(),
#     title='Flight Sensor Timeseries'
# )
# plt.show()
